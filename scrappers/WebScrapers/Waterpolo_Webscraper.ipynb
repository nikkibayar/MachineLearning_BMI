# %%
import requests
import re

# %%
def findHeight(line):
    h = re.search("<span>[1-7]{1,2}'[1-9]{1,2}&quot", line)
    return h

# %%
def findWeight(line):
    w = re.search("<span>[0-9]{3}\slbs", line)
    return w

# %%
def findImage(line):
    img = re.search("images.2016.8.22.[a-zA-Z_0-9]*.JPG", line)
    return img

# %%
all_data = []
def findAll():
    url = 'http://www.calbears.com/roster.aspx?path=mwpolo'
    user_agent = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36'
    headers = {'User-Agent': user_agent}
    r = requests.get(url, headers=headers)
    page = r
    count = 0
    prevLine = " "
    imgFound = False
    heightFound = False
    weightFound = False
    for line in r.iter_lines():
        if(count == 0):
            prevLine = str(line.decode("ISO-8859-1"))
            count = count + 1
            pass
        if(count!= 0):
            lineToUse = str(line.decode("ISO-8859-1"))
            if(imgFound == False):
                im = findImage(prevLine + lineToUse)
                if(im != None):
                    imgFound = True
                    image = im.group(0)
                else:
                    prevLine = lineToUse
            if(imgFound == True):
                if(heightFound == False):
                    h = findHeight(lineToUse)
                    if(h != None):
                        heightFound = True
                        height = h.group(0)
                if(heightFound == True and weightFound == False):
                    w = findWeight(lineToUse)
                    if(w != None):
                        weight = w.group(0)
                        data = {'url': 'http://www.calbears.com/roster.aspx?path=mwpolo',
                                'height': height, 'weight': weight, 'image': image}
                        all_data.append(data)
                        imgFound = False
                        heightFound = False
                        weightFound = False

# %%
findAll()

# %%
#go through array of objects and clean up data
import json
for x in range(0, len(all_data)):

    h = re.search("[1-7]{1}'[1-9]{1,2}", all_data[x]['height']) 
    all_data[x]['height'] = {
      'amount': str(h.group(0)),
      'unit': "cm"
    }
    
    w = re.search("[0-9]{1,3}\slbs", all_data[x]['weight'])
    all_data[x]['weight'] = {
        'amount': str(w.group(0)).split()[0],
        'unit': "kg"
    }
    all_data[x]['image'] = "http://www.calbears.com/" + all_data[x]['image']

print(json.dumps(all_data, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "height": {
#             "amount": "6'4",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Lazar_Andric_DZ_08122016_109.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "202",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "6'3",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Bernardo_Oliveira_DZ_08122016_157.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "198",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "6'2",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Kevin_LeVine_DZ_08122016_114.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "182",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "6'5",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Spencer_Tagg_DZ_08122016_138.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "180",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "6'2",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Pedro_Stellet_DZ_08122016_155.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "215",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "5'11",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Farrel_South_DZ_08122016_106.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "206",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "5'11",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Safak_Simsek_DZ_08122016_160.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "180",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "6'3",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Nicholas_Carniglia_DZ_08122016_102.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "205",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "6'4",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Mikey_Williams_DZ_08122016_162.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "200",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "6'7",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Nick_Bisconti_DZ_08122016_127.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "205",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "6'3",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Thomas_Carroll_DZ_08122016_111.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "216",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "6'1",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/J_D_Ratchford_DZ_08122016_117.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "164",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "6'1",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Odysseas_Masmanidis_DZ_08122016_132.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "228",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "6'2",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Vassilis_Tzavaras_DZ_08122016_130.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "205",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "6'5",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Timothy_Simenc_DZ_08122016_139.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "225",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "6'1",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Johnny_Hooper_DZ_08122016_126.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "182",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "6'2",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Chase_Hamming_DZ_08122016_122.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "185",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "6'3",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Conor_Neumann_DZ_08122016_103.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "214",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "6'2",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Matt_Sherburne_DZ_08122016_119.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "209",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "6'2",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Gianni_Taranto_DZ_08122016_143.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "190",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "5'11",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Duncan_Froomer_DZ_08122016_150.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "175",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "6'4",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Jackson_Hettler_DZ_08122016_148.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "193",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "6'3",
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Cade_Kruse_DZ_08122016_151.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": "205",
#             "unit": "kg"
#         }
#     }
# ]

# %%
#working on converting metrics
def convertMetrics():
    for x in range(0, len(all_data)):
        weight = all_data[x]['weight']['amount']
        all_data[x]['weight']['amount'] = float(weight) * .453  
        h = re.split("[']", all_data[x]['height']['amount'])
        height = (int(h[0]) * 12 + int(h[1])) * 2.54
        all_data[x]['height']['amount'] = height

# %%
print(json.dumps(all_data, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "height": {
#             "amount": 193.04,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Lazar_Andric_DZ_08122016_109.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 91.506,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 190.5,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Bernardo_Oliveira_DZ_08122016_157.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 89.694,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 187.96,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Kevin_LeVine_DZ_08122016_114.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 82.446,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 195.58,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Spencer_Tagg_DZ_08122016_138.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 81.54,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 187.96,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Pedro_Stellet_DZ_08122016_155.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 97.395,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 180.34,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Farrel_South_DZ_08122016_106.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 93.318,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 180.34,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Safak_Simsek_DZ_08122016_160.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 81.54,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 190.5,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Nicholas_Carniglia_DZ_08122016_102.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 92.86500000000001,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 193.04,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Mikey_Williams_DZ_08122016_162.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 90.60000000000001,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 200.66,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Nick_Bisconti_DZ_08122016_127.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 92.86500000000001,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 190.5,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Thomas_Carroll_DZ_08122016_111.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 97.848,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 185.42000000000002,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/J_D_Ratchford_DZ_08122016_117.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 74.292,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 185.42000000000002,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Odysseas_Masmanidis_DZ_08122016_132.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 103.284,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 187.96,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Vassilis_Tzavaras_DZ_08122016_130.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 92.86500000000001,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 195.58,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Timothy_Simenc_DZ_08122016_139.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 101.925,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 185.42000000000002,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Johnny_Hooper_DZ_08122016_126.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 82.446,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 187.96,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Chase_Hamming_DZ_08122016_122.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 83.805,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 190.5,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Conor_Neumann_DZ_08122016_103.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 96.94200000000001,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 187.96,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Matt_Sherburne_DZ_08122016_119.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 94.677,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 187.96,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Gianni_Taranto_DZ_08122016_143.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 86.07000000000001,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 180.34,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Duncan_Froomer_DZ_08122016_150.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 79.275,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 193.04,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Jackson_Hettler_DZ_08122016_148.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 87.429,
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": 190.5,
#             "unit": "cm"
#         },
#         "image": "http://www.calbears.com/images/2016/8/22/Cade_Kruse_DZ_08122016_151.JPG",
#         "url": "http://www.calbears.com/roster.aspx?path=mwpolo",
#         "weight": {
#             "amount": 92.86500000000001,
#             "unit": "kg"
#         }
#     }
# ]

# %%
def calcBMI(height, weight):
    height = height / 100
    bmi = weight/(height * height)
    return bmi

# %%
import urllib
import urllib.request
from urllib.request import urlretrieve
from PIL import Image
import random
import cv2
def imagesToFolder():
    count = 0
    for x in range(0, len(all_data)):
        try:
            height = int(all_data[x]['height']['amount'])
            weight = int(all_data[x]['weight']['amount'])
            if(len(str(weight)) > 1): 
                count = count + 1
                bmiNum = calcBMI(height, weight)
                url = all_data[x]['image']
                print(weight)
                nameOfImage = "B-"+ str(bmiNum) + "H-" + str(height) + "W-" + str(weight) + "-" + str(hash(random.random())) + "6_8.jpg"
                path = "/Users/nikki-genlife/Desktop/anaconda/all_usable_imageNames"
                response = urllib.request.urlopen(url)
                y = response.read()
                fd = open(path + "/" + nameOfImage, "wb")
                fd.write(y)
                fd.close()
            else:
                pass
        except urllib.error.HTTPError:
            pass

# %%
#imagesToFolder()
