# %%
import requests
import lxml 
import numpy as np
import re, json
import sys
import urllib.request
from urllib.request import urlopen
from lxml import html
from elasticsearch import Elasticsearch
import logging

r = requests.get("http://height-weight-chart.com")
urls = []

# %%
#Goes through and gets ending part of url for each specific image
for line in r.iter_lines():
    m = re.search("[0-9]{3}-[0-9]{3}.html", str(line.decode('utf-8')))
    if m == None:
        x = 0 
    else:
        urls.append(m.group(0))

# %%
allUrls = urls

# %%
def findHeight(line):
    h = re.search("[0-9]{1,3}\scm", line)
    return h

# %%
def findWeight(line):
    w = re.search("[0-9]{1,3}\skg", line)
    return w

# %%
def findImage(line):
    m = re.search("largepic.*[0-9]{3}-[0-9]{3}.*.jpg", line)
    return m

# %%
data_list = []
save_urls = []
def findAll():
    for url in urls:
        q = requests.get("http://height-weight-chart.com/" + url) 
        save_urls.append(q.content)
        colorNotFound = True
        heightFound = False
        weightFound = False
        imageFound = False
        height = 0
        weight = 0
        #x = "h"
        for line in q:
            lineToUse = str(line.decode("ISO-8859-1"))
            #need a way to also get the next line
            #print(" ")
            #print(lineToUse)

            if(colorNotFound == True):
                z = re.search("color=#0000FF", lineToUse)
                if z != None:
                    colorNotFound = False
                    h = findHeight(lineToUse)
                    if h != None:
                        heightFound = True
                        height = str(h.group(0))
                        w = findWeight(lineToUse) # want to add next line to it
                        #x = lineToUse
                        if w != None:
                            weightFound = True
                            weight = str(w.group(0))
            else:  
                if(heightFound == False):
                    h = findHeight(lineToUse)
                    if h != None:
                        heightFound = True
                        height = str(h.group(0))
                        w = findWeight(lineToUse)
                        if w != None:
                            weightFound = True
                            weight = str(w.group(0))

                elif(heightFound == True and weightFound == False):
                    w = findWeight(lineToUse)
                    if w != None:
                        weight = str(w.group(0))
                        weightFound = True
                        m = findImage(lineToUse)
                        if m != None:
                            data = {'url': "http://height-weight-chart.com/" + url, 'image': str(m.group(0)),
                                'height': height, 'weight': weight}
                            #print(data)
                            data_list.append(data)
                            colorNotFound = True
                            heightFound = False
                            weightFound = False
                            imageFound = False
                elif(heightFound == True and weightFound == True and imageFound == False):
                        m = findImage(lineToUse)
                        if m != None:
                            data = {'url': "http://height-weight-chart.com/" + url, 'image': str(m.group(0)),
                                'height': height, 'weight': weight}
                            data_list.append(data)
                            colorNotFound = True
                            heightFound = False
                            weightFound = False
                            imageFound = False

# %%
findAll()

# %%
print(data_list)
# Out:
# [{'url': 'http://height-weight-chart.com/608-180.html', 'image': 'largepic" src="l/608-180_Dan_L1.jpg', 'height': '203 cm', 'weight': '82 kg'}, {'url': 'http://height-weight-chart.com/611-490.html', 'image': 'largepic" src="l/611-490_Xavier_L1.jpg', 'height': '211 cm', 'weight': '222 kg'}, {'url': 'http://height-weight-chart.com/607-170.html', 'image': 'largepic" src="l/607-170_Lincoln_L1.jpg', 'height': '201 cm', 'weight': '77 kg'}, {'url': 'http://height-weight-chart.com/607-210.html', 'image': 'largepic" src="l/607-210_Allan_L1.jpg', 'height': '201 cm', 'weight': '95 kg'}, {'url': 'http://height-weight-chart.com/606-240.html', 'image': 'largepic" src="l/606-240_Kenny_L1.jpg', 'height': '198 cm', 'weight': '109 kg'}, {'url': 'http://
# %%
#go through array of objects and clean up data
import json
for x in range(0, len(data_list)):

    h = re.search("[0-9]{1,3}\s*cm", data_list[x]['height'])

    data_list[x]['height'] = {
      'amount': str(h.group(0)).split()[0],
      'unit': str(h.group(0)).split()[1]
    }
    
    w = re.search("[0-9]{1,3}\skg", data_list[x]['weight'])
    data_list[x]['weight'] = {
        'amount': str(w.group(0)).split()[0],
        'unit': str(w.group(0)).split()[1]
    }
    
    
    i = re.search("[0-9]{3}-[0-9]{3}.*.jpg", data_list[x]['image'])
    data_list[x]['image'] = "http://height-weight-chart.com/l/" + str(i.group(0))

print(json.dumps(data_list, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "height": {
#             "amount": "203",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/608-180_Dan_L1.jpg",
#         "url": "http://height-weight-chart.com/608-180.html",
#         "weight": {
#             "amount": "82",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "211",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/611-490_Xavier_L1.jpg",
#         "url": "http://height-weight-chart.com/611-490.html",
#         "weight": {
#             "amount": "222",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "201",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/607-170_Lincoln_L1.jpg",
#         "url": "http://height-weight-chart.com/607-170.html",
#         "weight": {
#             "amount": "77",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "201",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/607-210_Allan_L1.jpg",
#         "url": "http://height-weight-chart.com/607-210.html",
#         "weight": {
#             "amount": "95",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "198",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/606-240_Kenny_L1.jpg",
#         "url": "http://height-weight-chart.com/606-240.html",
#         "weight": {
#             "amount": "109",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "198",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/606-250_Dale_L1.jpg",
#         "url": "http://height-weight-chart.com/606-250.html",
#         "weight": {
#             "amount": "113",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "198",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/606-260_Cees_L1.jpg",
#         "url": "http://height-weight-chart.com/606-260.html",
#         "weight": {
#             "amount": "118",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "198",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/606-290_Jesse_L1.jpg",
#         "url": "http://height-weight-chart.com/606-290.html",
#         "weight": {
#             "amount": "2",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "198",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/606-370_Vance_L1.jpg",
#         "url": "http://height-weight-chart.com/606-370.html",
#         "weight": {
#             "amount": "168",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "198",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/606-380_Michael_L1.jpg",
#         "url": "http://height-weight-chart.com/606-380.html",
#         "weight": {
#             "amount": "2",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "196",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/605-140_Wolf_L1.jpg",
#         "url": "http://height-weight-chart.com/605-140.html",
#         "weight": {
#             "amount": "64",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "196",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/605-180_Hartley_L1.jpg",
#         "url": "http://height-weight-chart.com/605-180.html",
#         "weight": {
#             "amount": "82",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "196",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/605-220_John_L1.jpg",
#         "url": "http://height-weight-chart.com/605-220.html",
#         "weight": {
#             "amount": "100",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "196",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/605-230_Jeremy_L1.jpg",
#         "url": "http://height-weight-chart.com/605-230.html",
#         "weight": {
#             "amount": "104",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "196",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/605-270_Pete_L1.jpg",
#         "url": "http://height-weight-chart.com/605-270.html",
#         "weight": {
#             "amount": "122",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "196",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/605-280_George_L1.jpg",
#         "url": "http://height-weight-chart.com/605-280.html",
#         "weight": {
#             "amount": "127",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "196",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/605-300_Ben_L1.jpg",
#         "url": "http://height-weight-chart.com/605-300.html",
#         "weight": {
#             "amount": "136",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "193",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/604-210_Michael_L1.jpg",
#         "url": "http://height-weight-chart.com/604-210.html",
#         "weight": {
#             "amount": "95",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount":

#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "170",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/507-160_Chris_L2.jpg",
#         "url": "http://height-weight-chart.com/507-160.html",
#         "weight": {
#             "amount": "73",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "170",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/507-170_Jackie_L1.jpg",
#         "url": "http://height-weight-chart.com/507-170.html",
#         "weight": {
#             "amount": "77",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "170",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/507-180_Caralyn_L1.jpg",
#         "url": "http://height-weight-chart.com/507-180.html",
#         "weight": {
#             "amount": "82",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "170",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/507-200_Lisa_L1.jpg",
#         "url": "http://height-weight-chart.com/507-200.html",
#         "weight": {
#             "amount": "91",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "170",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/507-210_Sarah_L1.jpg",
#         "url": "http://height-weight-chart.com/507-210.html",
#         "weight": {
#             "amount": "95",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "170",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/507-220_Jillo_L1.jpg",
#         "url": "http://height-weight-chart.com/507-220.html",
#         "weight": {
#             "amount": "100",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "170",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/507-240_Zhenya_L1.jpg",
#         "url": "http://height-weight-chart.com/507-240.html",
#         "weight": {
#             "amount": "9",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "170",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/507-260_Beth_L1.jpg",
#         "url": "http://height-weight-chart.com/507-260.html",
#         "weight": {
#             "amount": "118",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "170",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/507-270_Barb_L1.jpg",
#         "url": "http://height-weight-chart.com/507-270.html",
#         "weight": {
#             "amount": "2",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "170",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/507-280_Dasha_L1.jpg",
#         "url": "http://height-weight-chart.com/507-280.html",
#         "weight": {
#             "amount": "7",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "170",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/507-310_Jacinta_L1.jpg",
#         "url": "http://height-weight-chart.com/507-310.html",
#         "weight": {
#             "amount": "141",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "170",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/507-320_Brandy_L1.jpg",
#         "url": "http://height-weight-chart.com/507-320.html",
#         "weight": {
#             "amount": "145",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "170",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/507-380_Lisa_L1.jpg",
#         "url": "http://height-weight-chart.com/507-380.html",
#         "weight": {
#             "amount": "172",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "168",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/506-090_eve_L1.jpg",
#         "url": "http://height-weight-chart.com/506-090.html",
#         "weight": {
#             "amount": "41",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "168",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/506-100_Jill_L1.jpg",
#         "url": "http://height-weight-chart.com/506-100.html",
#         "weight": {
#             "amount": "45",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "168",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/506-110_Margaret_L1.jpg",
#         "url": "http://height-weight-chart.com/506-110.html",
#         "weight": {
#             "amount": "50",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "168",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/506-120_CLB_L1.jpg",
#         "url": "http://height-weight-chart.com/506-120.html",
#         "weight": {
#             "amount": "54",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "168",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/506-130_Furry_L1.jpg",
#         "url": "http://height-weight-chart.com/506-130.html",
#         "weight": {
#             "amount": "59",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "168",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/506-150_Anthony_L1.jpg",
#         "url": "http://height-weight-chart.com/506-150.html",
#         "weight": {
#             "amount": "68",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "168",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/506-160_Caralyn_L1.jpg",
#         "url": "http://height-weight-chart.com/506-160.html",
#         "weight": {
#             "amount": "73",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "168",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/506-180_Leah_L2.jpg",
#         "url": "http://height-weight-chart.com/506-180.html",
#         "weight": {
#             "amount": "82",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "168",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/506-190_Mike_L1.jpg",
#         "url": "http://height-weight-chart.com/506-190.html",
#         "weight": {
#             "amount": "86",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "168",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/506-200_kate_L1.jpg",
#         "url": "http://height-weight-chart.com/506-200.html",
#         "weight": {
#             "amount": "91",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "168",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/506-215_Paul_L1.jpg",
#         "url": "http://height-weight-chart.com/506-210.html",
#         "weight": {
#             "amount": "95",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "168",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/506-220_Renee_L1.jpg",
#         "url": "http://height-weight-chart.com/506-220.html",
#         "weight": {
#             "amount": "100",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "168",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/506-240_Sarah_L1.jpg",
#         "url": "http://height-weight-chart.com/506-240.html",
#         "weight": {
#             "amount": "109",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "168",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/506-260_Amanda_L1.jpg",
#         "url": "http://height-weight-chart.com/506-260.html",
#         "weight": {
#             "amount": "118",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "168",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/506-270_Nee_L1.jpg",
#         "url": "http://height-weight-chart.com/506-270.html",
#         "weight": {
#             "amount": "122",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "168",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/506-280_Kelly_L1.jpg",
#         "url": "http://height-weight-chart.com/506-280.html",
#         "weight": {
#             "amount": "7",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "165",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/505-090_samantha_L1.jpg",
#         "url": "http://height-weight-chart.com/505-090.html",
#         "weight": {
#             "amount": "41",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "165",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/505-100_Kati_L1.jpg",
#         "url": "http://height-weight-chart.com/505-100.html",
#         "weight": {
#             "amount": "45",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
# ...
#         "weight": {
#             "amount": "59",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "163",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/504-135_Peggy_L1.jpg",
#         "url": "http://height-weight-chart.com/504-140.html",
#         "weight": {
#             "amount": "64",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "163",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/504-150_Bethan_L1.jpg",
#         "url": "http://height-weight-chart.com/504-150.html",
#         "weight": {
#             "amount": "68",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "163",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/504-160_Emily_L1.jpg",
#         "url": "http://height-weight-chart.com/504-160.html",
#         "weight": {
#             "amount": "73",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "163",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/504-180_Nela_L1.jpg",
#         "url": "http://height-weight-chart.com/504-180.html",
#         "weight": {
#             "amount": "82",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "163",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/504-185_rachel_L1.jpg",
#         "url": "http://height-weight-chart.com/504-190.html",
#         "weight": {
#             "amount": "86",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "163",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/504-200_Diedre_L1.jpg",
#         "url": "http://height-weight-chart.com/504-200.html",
#         "weight": {
#             "amount": "91",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "163",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/504-210_Erin_L1.jpg",
#         "url": "http://height-weight-chart.com/504-210.html",
#         "weight": {
#             "amount": "95",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "163",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/504-230_Mary_L1.jpg",
#         "url": "http://height-weight-chart.com/504-230.html",
#         "weight": {
#             "amount": "104",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "163",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/504-240_Deneen_L1.jpg",
#         "url": "http://height-weight-chart.com/504-240.html",
#         "weight": {
#             "amount": "109",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "160",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/503-090_Caitlin_L1.jpg",
#         "url": "http://height-weight-chart.com/503-090.html",
#         "weight": {
#             "amount": "41",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "160",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/503-100_Emily_L1.jpg",
#         "url": "http://height-weight-chart.com/503-100.html",
#         "weight": {
#             "amount": "45",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "160",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/503-110_Pati_L1.jpg",
#         "url": "http://height-weight-chart.com/503-110.html",
#         "weight": {
#             "amount": "50",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "160",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/503-150_melissa_L1.jpg",
#         "url": "http://height-weight-chart.com/503-150.html",
#         "weight": {
#             "amount": "68",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "160",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/503-190_Miriam_L1.jpg",
#         "url": "http://height-weight-chart.com/503-190.html",
#         "weight": {
#             "amount": "86",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "160",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/503-200_Ashley_L1.jpg",
#         "url": "http://height-weight-chart.com/503-200.html",
#         "weight": {
#             "amount": "91",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "160",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/503-250_Lyons_L1.jpg",
#         "url": "http://height-weight-chart.com/503-250.html",
#         "weight": {
#             "amount": "113",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "160",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/503-270_Natasha_L1.jpg",
#         "url": "http://height-weight-chart.com/503-270.html",
#         "weight": {
#             "amount": "122",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "160",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/503-300_Jean_L1.jpg",
#         "url": "http://height-weight-chart.com/503-300.html",
#         "weight": {
#             "amount": "136",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "160",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/503-370_Lynn_L1.jpg",
#         "url": "http://height-weight-chart.com/503-370.html",
#         "weight": {
#             "amount": "168",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "157",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/502-100_Elise_L1.jpg",
#         "url": "http://height-weight-chart.com/502-100.html",
#         "weight": {
#             "amount": "45",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "157",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/502-120_Heather_L1.jpg",
#         "url": "http://height-weight-chart.com/502-120.html",
#         "weight": {
#             "amount": "54",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount":

#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/410-100_Cece_L1.jpg",
#         "url": "http://height-weight-chart.com/410-100.html",
#         "weight": {
#             "amount": "45",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "147",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/410-110_Kaye_L1.jpg",
#         "url": "http://height-weight-chart.com/410-110.html",
#         "weight": {
#             "amount": "50",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "147",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/410-160_Sarah_L1.jpg",
#         "url": "http://height-weight-chart.com/410-160.html",
#         "weight": {
#             "amount": "73",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "147",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/410-170_Tiffany_L1.jpg",
#         "url": "http://height-weight-chart.com/410-170.html",
#         "weight": {
#             "amount": "77",
#             "unit": "kg"
#         }
#     },
#     {
#         "height": {
#             "amount": "147",
#             "unit": "cm"
#         },
#         "image": "http://height-weight-chart.com/l/410-190_TFergusu_L1.jpg",
#         "url": "http://height-weight-chart.com/410-190.html",
#         "weight": {
#             "amount": "86",
#             "unit": "kg"
#         }
#     }
# ]

# %%
def calcBMI(height, weight):
    height = height / 100
    bmi = weight/(height * height)
    return bmi

# %%
print(len(data_list))
# Out:
# 216

# %%
import urllib
import urllib.request
from urllib.request import urlretrieve
from PIL import Image
import random
import cv2
def imagesToFolder():
    count = 0
    for x in range(0, len(data_list)):
        try:
            height = int(data_list[x]['height']['amount'])
            weight = int(data_list[x]['weight']['amount'])
            if(len(str(weight)) > 1): 
                count = count + 1
                bmiNum = calcBMI(height, weight)
                url = data_list[x]['image']
                print(weight)
                nameOfImage = "B-"+ str(bmiNum) + "H-" + str(height) + "W-" + str(weight) + "-" + str(hash(random.random())) + "6_8.jpg"
                path = "/Users/nikki-genlife/Desktop/anaconda/all_usable_imageNames"
                response = urllib.request.urlopen(url)
                y = response.read()
                fd = open(path + "/" + nameOfImage, "wb")
                fd.write(y)
                fd.close()
            else:
                pass
        except urllib.error.HTTPError:
            pass
    print(count)

# %%
# Out:
# 82
# 222
# 77
# 95
# 109
# 113
# 118
# 168
# 64
# 82
# 100
# 104
# 122
# 127
# 136
# 95
# 100
# 104
# 118
# 145
# 236
# 91
# 100
# 104
# 141
# 64
# 77
# 100
# 113
# 132
# 218
# 64
# 77
# 86
# 113
# 77
# 91
# 100
# 104
# 127
# 136
# 141
# 145
# 150
# 50
# 54
# 59
# 73
# 82
# 86
# 91
# 95
# 104
# 118
# 122
# 127
# 132
# 141
# 163
# 168
# 54
# 59
# 64
# 68
# 73
# 86
# 91
# 122
# 127
# 45
# 50
# 54
# 59
# 64
# 73
# 77
# 82
# 86
# 91
# 100
# 104
# 122
# 136
# 141
# 45
# 50
# 54
# 59
# 64
# 68
# 82
# 100
# 104
# 113
# 132
# 150
# 177
# 54
# 59
# 64
# 68
# 73
# 77
# 82
# 91
# 95
# 100
# 118
# 141
# 145
# 172
# 41
# 45
# 50
# 54
# 59
# 68
# 73
# 82
# 86
# 91
# 95
# 100
# 109
# 118
# 122
# 41
# 45
# 59
# 73
# 77
# 86
# 91
# 95
# 109
# 113
# 122
# 136
# 45
# 50
# 54
# 59
# 64
# 68
# 73
# 82
# 86
# 91
# 95
# 104
# 109
# 41
# 45
# 50
# 68
# 86
# 91
# 113
# 122
# 136
# 168
# 45
# 54
# 59
# 100
# 113
# 132
# 150
# 45
# 68
# 73
# 77
# 95
# 41
# 45
# 50
# 54
# 64
# 82
# 95
# 100
# 45
# 68
# 77
# 104
# 41
# 45
# 50
# 73
# 77
# 86
# 191
